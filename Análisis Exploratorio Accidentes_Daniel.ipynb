# %% [markdown]
# # Análisis Exploratiorio Tabla Accidentes

# %%
import os
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Extracción de datos de la BD SQL Server

# %%
# class SQLServer:
#     def __init__(self, server_name, database_name, user_name, password):
#         self.server_name = server_name
#         self.database_name = database_name
#         self.user_name = user_name
#         self.password = password
#         self.connection_string = f'DRIVER={{SQL Server}};SERVER={self.server_name};DATABASE={self.database_name};UID={self.user_name};PWD={self.password}'
#         self.connection = pyodbc.connect(self.connection_string)

#     def query_to_dataframe(self, query):
#             df = pd.read_sql(query, self.connection)
#             return df

# %%
# Crea una instancia de la clase SQLServer
# sql_server = SQLServer('TVM-PAPP02-VIC', 'AnalystBi', 'ajusta', 'Holading2022*')

# %%
# Define la consulta
# query = 'SELECT * FROM Ajuasta_ACCIDENTES_TBL'

# %%
# Obtiene un dataframe de la tabla 'nombre_tabla'
# df = sql_server.query_to_dataframe(query)
# df.head()

# %% [markdown]
# ## Importación de datos desde un Excel

# %%
root_ = r'C:\Users\juans'
sharepoint = r'Vicman Services S.A.S\INFORMES ANALITICA - Documentos\AJUSTA\Análisis Accidentes Ajusta'
nombre_archivo = 'Ajusta_ACCIDENTES_TBL.xlsx' 
df_fullpath = os.path.join(root_, sharepoint, nombre_archivo)

df = pd.read_excel(df_fullpath, sheet_name='ACC_COPIA')
df.head()
# Out:
#    Numero  Documento   Placa Fecha_reporte           Fecha_accidente  \
# 0    4491        NaN  WTM312    2017-04-13   8/07/2016 12:00:00 a.m.
# 1    4678        NaN  TDW493    2017-04-15   28/07/2016 6:30:00 a.m.
# 2    4693        NaN  VFA225    2017-04-13  30/08/2016 12:00:00 a.m.
# 3    5019        NaN  VFB434    2017-04-13  18/08/2016 11:00:00 p.m.
# 4    5054        NaN  TKI371    2017-04-14  28/09/2016 12:05:00 p.m.
#
#    id_compania                       nm_compania  cliente_cliente  \
# 0    860037013  COMPAÑIA MUNDIAL DE SEGUROS S.A.        860020096
# 1    860037013  COMPAÑIA MUNDIAL DE SEGUROS S.A.        890101933
# 2    860037013  COMPAÑIA MUNDIAL DE SEGUROS S.A.        800089388
# 3    860037013  COMPAÑIA MUNDIAL DE SEGUROS S.A.        800174909
# 4    860037013  COMPAÑIA MUNDIAL DE SEGUROS S.A.        811036213
#
#                  nm_cliente                   nm_creado  ...  \
# 0               CONALCETECE           PROVISIONAL SIETE  ...
# 1                 COOCHOTAX               YIN WEI QIAHG  ...
# 2           TAMPA D.C. S.A.           PROVISIONAL SIETE  ...
# 3               TAX EXPRESS           PROVISIONAL SIETE  ...
# 4  TRANSPORTES BRASIL S.A.S  JOSE LUIS PEÑALOZA JIMENEZ  ...
#
#   revision_especial entidad_agente                           Hipotesis_agente  \
# 0                NO            NaN                                      OTRA.
# 1                NO            NaN  DESOBEDECER SEÑALES O NORMAS DE TRÁNSITO.
# 2                NO            NaN  DESOBEDECER SEÑALES O NORMAS DE TRÁNSITO.
# 3                NO            NaN                        ADELANTAR CERRANDO.
# 4                NO            NaN                              SIN HIPÓTESIS
#
#               fehca_nac_per  modelo dia_accidente            hora_acidente  \
# 0  23/10/1969 12:00:00 a.m.  2005.0       VIERNES  00:00 A.M. - 05:59 A.M.
# 1   2/07/1981 12:00:00 a.m.  2013.0        JUEVES  06:00 A.M. - 11:59 A.M.
# 2                       NaN  2009.0        MARTES  00:00 A.M. - 05:59 A.M.
# 3  10/09/1965 12:00:00 a.m.  2010.0        JUEVES  06:00 P.M. - 11:59 P.M.
# 4   3/08/1966 12:00:00 a.m.  2008.0     MIERCOLES  12:00 P.M. - 05:59 P.M.
#
#      empresas_cod obs_hipotesis_agente  \
# 0  otras empresas   INVASION DE CARRIL
# 1  otras empresas                  NaN
# 2  otras empresas                  NaN
# 3  otras empresas                  NaN
# 4  otras empresas                  NaN
#
#                                      curos_hipotesis
# 0                                                NaN
# 1  Importancia del lenguaje vial en la conducción...
# 2  Importancia del lenguaje vial en la conducción...
# 3  Seguridad basada en el comportamiento -  Marco...
# 4                                                NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Análisis Exploratorio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69921 entries, 0 to 69920
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Numero                69921 non-null  int64
#  1   Documento             2013 non-null   float64
#  2   Placa                 69921 non-null  object
#  3   Fecha_reporte         69921 non-null  datetime64[ns]
#  4   Fecha_accidente       69921 non-null  object
#  5   id_compania           69921 non-null  int64
#  6   nm_compania           69921 non-null  object
#  7   cliente_cliente       69921 non-null  int64
#  8   nm_cliente            69921 non-null  object
#  9   nm_creado             69918 non-null  object
#  10  tipo_accidente        69919 non-null  object
#  11  nm_ciudad             69921 non-null  object
#  12  nm_departamento       69921 non-null  object
#  13  id_conductor          69249 non-null  float64
#  14  nm_conductor          69116 non-null  object
#  15  poliza_rcc            6731 non-null   object
#  16  poliza_rce            63897 non-null  object
#  17  poliza_rcce           10 non-null     float64
#  18  poliza_rcee           16 non-null     object
#  19  poliza_tr             1038 non-null   object
#  20  poliza_plo            9 non-null      object
#  21  poliza_ip             0 non-null      float64
#  22  poliza_tercero        13 non-null     float64
#  23  valor_reserva         69095 non-null  float64
#  24  valor_reserva_actual  69095 non-null  float64
#  25  todo_riesgo           69921 non-null  object
#  26  tipo_servicio         68840 non-null  object
#  27  nombre_agente         1998 non-null   object
#  28  grado_agemte          2485 non-null   object
#  29  placa_agente          2531 non-null   object
#  30  revision_especial     69921 non-null  object
#  31  entidad_agente        1963 non-null   object
#  32  Hipotesis_agente      69921 non-null  object
#  33  fehca_nac_per         60891 non-null  object
#  34  modelo                68511 non-null  float64
#  35  dia_accidente         69921 non-null  object
#  36  hora_acidente         69921 non-null  object
#  37  empresas_cod          69921 non-null  object
#  38  obs_hipotesis_agente  8414 non-null   object
#  39  curos_hipotesis       31956 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(3), object(28)
# memory usage: 21.3+ MB

# %%
df.describe()
# Out:
#               Numero     Documento  id_compania  cliente_cliente  \
# count   69921.000000  2.013000e+03      69921.0     6.992100e+04
# mean   134340.817136  6.303384e+08  860037013.0     1.448821e+09
# std     20897.426956  6.823046e+08          0.0     3.407213e+09
# min       111.000000  0.000000e+00  860037013.0     7.144500e+06
# 25%    116915.000000  7.176300e+07  860037013.0     8.600259e+08
# 50%    134589.000000  1.014273e+09  860037013.0     8.909093e+08
# 75%    152252.000000  1.067859e+09  860037013.0     9.003657e+08
# max    169919.000000  1.078757e+10  860037013.0     9.003657e+10
#
#        id_conductor   poliza_rcce  poliza_ip  poliza_tercero  valor_reserva  \
# count  6.924900e+04  1.000000e+01        0.0    1.300000e+01   6.909500e+04
# mean   1.042362e+11  1.800056e+09        NaN    3.957410e+08   1.586410e+06
# std    4.354151e+12  6.324752e+08        NaN    7.121175e+08   5.107594e+06
# min   -1.000000e+06  0.000000e+00        NaN    1.040032e+08   0.000000e+00
# 25%    1.949509e+07  2.000018e+09        NaN    1.040037e+08   0.000000e+00
# 50%    7.982006e+07  2.000026e+09        NaN    1.040057e+08   5.929320e+05
# 75%    1.017202e+09  2.000068e+09        NaN    1.040092e+08   1.763818e+06
# max    7.278495e+14  2.000256e+09        NaN    2.000286e+09   4.679760e+08
#
#        valor_reserva_actual        modelo
# count          6.909500e+04  68511.000000
# mean           1.119698e+06   2023.513085
# std            8.247284e+06    531.808262
# min            0.000000e+00      0.000000
# 25%            0.000000e+00   2008.000000
# 50%            0.000000e+00   2012.000000
# 75%            4.576145e+05   2015.000000
# max            1.066713e+09  22013.000000
